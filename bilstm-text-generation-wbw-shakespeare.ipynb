# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.optim import AdamW

from sklearn.model_selection import train_test_split

# %%
import requests

url = "https://www.gutenberg.org/files/100/100-0.txt"
response = requests.get(url)
text_data = response.text

# Save the dataset locally
with open("shakespeare.txt", "w", encoding="utf-8") as file:
    file.write(text_data)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
import re

def clean_text(text):
    text = text.lower()
    
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)  
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

with open("shakespeare.txt", "r", encoding="utf-8") as file:
    raw_text = file.read()

cleaned_text = clean_text(raw_text)

# %%
len(cleaned_text)
# Out:
# 5029939

# %%
cleaned_text_list = cleaned_text.split(" ")

# %%
cleaned_text_list = [word for word in cleaned_text_list if not word.startswith("_")]

# %%
vocab = sorted(set(cleaned_text_list))

# %%
vocab = [word for word in vocab if not word.startswith('_')]

# %%
vocab_size = len(vocab)

# %%
vocab_size
# Out:
# 30766

# %%
word2idx = dict((word, idx) for idx, word in enumerate(vocab))
idx2word = dict((idx, word) for idx, word in enumerate(vocab))

# %%
step_size = 20
text_length = 10
X = []
y = []
for i in range(0, len(cleaned_text_list)-text_length, step_size):
    X.append(cleaned_text_list[i:i+text_length])
    y.append(cleaned_text_list[i+text_length])

# %%
len(X), len(y)
# Out:
# (47901, 47901)

# %%
glove_path = "/kaggle/input/glove-embeddings/glove.6B.200d.txt"
glove_embeddings = dict()

with open(glove_path,  "r", encoding = "utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        embeddings = np.asarray(values[1:], dtype = "float32")
        glove_embeddings[word] = embeddings

# %%
df = pd.DataFrame({"texts" : X, "target" : y})

# %%
len(df)
# Out:
# 47901

# %%
def tokenize(text):
    tokens = []
    for t in text:
        tokens.append(word2idx[t])
    return tokens

df["texts_tokenized"] = df["texts"].apply(tokenize)
df["target_tokenized"] = df["target"].apply(lambda x: word2idx[x])

# %%
df.head()
# Out:
#                                                texts   target  \
# 0  [start, of, the, project, gutenberg, ebook, th...  william
# 1  [that, ends, well, the, tragedy, of, antony, a...      you
# 2  [coriolanus, cymbeline, the, tragedy, of, haml...    first
# 3  [of, king, henry, the, fourth, the, life, of, ...      the
# 4  [second, part, of, king, henry, the, sixth, th...       of
#
#                                      texts_tokenized  target_tokenized
# 0  [25157, 18183, 26614, 20691, 11931, 8364, 2661...             30130
# 1  [26589, 8667, 29767, 26614, 27375, 18183, 1044...             30686
# 2  [5711, 6384, 26614, 27375, 18183, 12048, 20536...             10044
# 3  [18183, 14534, 12537, 26614, 10666, 26614, 152...             26614
# 4  [23207, 19010, 18183, 14534, 12537, 26614, 241...             18183

# %%
embedding_dim = 200
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for words, idx in word2idx.items():
    if words in glove_embeddings.keys():
        embedding_matrix[idx] = glove_embeddings[words]
    else:
        embedding_matrix[idx] = np.zeros(embedding_dim)

# %%
def embeddings(tokens):
    embedding = []
    for t in tokens:
        embedding.append(embedding_matrix[t])
    return np.array(embedding)

text_embeddings = df["texts_tokenized"].apply(embeddings)
target_tokenized = df["target_tokenized"]

# %%
target_tensors = torch.tensor(target_tokenized, dtype = torch.long)
text_tensors = torch.tensor(text_embeddings, dtype = torch.float32)
# Out:
# <ipython-input-23-2b70a92c78ce>:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   text_tensors = torch.tensor(text_embeddings, dtype = torch.float32)

# %%
target_tensors.shape, text_tensors.shape
# Out:
# (torch.Size([47901]), torch.Size([47901, 10, 200]))

# %%
X_train, y_train = text_tensors, target_tensors

# %%
text_tensors.shape
# Out:
# torch.Size([47901, 10, 200])

# %%
class TextDataset(Dataset):
    def __init__(self, X, y):
        self.inputs = X
        self.target= y

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return {
            "inputs" : self.inputs[idx],
            "target" : self.target[idx]
        }

# %%
train_dataset = TextDataset(X_train, y_train)

# %%
batch_size = 32
train_dl = DataLoader(train_dataset, batch_size = batch_size, shuffle = False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
hidden_dim = 128
output_dim = vocab_size
num_layers = 5
dropout = 0.3

class Model(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, output_dim, num_layers, dropout):
        super(Model, self).__init__()
        self.bilstm = nn.LSTM(input_size = embedding_dim, hidden_size = hidden_dim, batch_first = True, num_layers = num_layers, bidirectional = True, dropout = dropout)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(2*hidden_dim, output_dim)

    def forward(self, inputs):
        output, _ = self.bilstm(inputs)
        output = self.dropout(output[:, -1, :])
        output = self.fc(output)
        return output

# %%
model = Model(embedding_dim, hidden_dim, output_dim, num_layers, dropout)
model.to(device)
# Out:
# Model(
#   (bilstm): LSTM(200, 128, num_layers=5, batch_first=True, dropout=0.3, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=30766, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)
loss_fn = nn.CrossEntropyLoss()

# %%
# %%time
num_epochs = 400
model_path = "best_model.pth"
best_accuracy = 0
losses = []
   
for epoch in range(num_epochs):
    print("="*100)
    print(f"EPOCH: {epoch+1}/{num_epochs}: ")
    print("-"*100)
    
    model.train()
    correct_prediction = 0 
    total_samples = 0  
    total_loss = 0 
    
    for batch in train_dl:
        inputs = batch["inputs"].to(device)
        target = batch["target"].to(device)

        optimizer.zero_grad()
        output = model(inputs)
        loss = loss_fn(output, target)

        preds = torch.argmax(output, dim=1)

        correct_prediction += (preds == target).sum().item() 
        total_samples += target.size(0) 

        total_loss += loss.item()
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm = 1.0)
        optimizer.step()
    
    accuracy = (correct_prediction / total_samples) * 100
    avg_loss = total_loss / len(train_dl)
    
    print(f"\tCorrect Predictions (Train Dataset): {accuracy:.2f}%")
    print(f"\tLoss: {avg_loss:.4f}")

    if accuracy >  best_accuracy:
        best_accuracy = accuracy
        torch.save(model.state_dict(), model_path)

print("Best Model Accuracy: ", best_accuracy)
# Out:
# ====================================================================================================
# EPOCH: 1/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 35.63%
# 	Loss: 3.3706
# ====================================================================================================
# EPOCH: 2/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 35.78%
# 	Loss: 3.3669
# ====================================================================================================
# EPOCH: 3/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 35.50%
# 	Loss: 3.3634
# ====================================================================================================
# EPOCH: 4/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 35.89%
# 	Loss: 3.3553
# ====================================================================================================
# EPOCH: 5/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 35.83%
# 	Loss: 3.3616
# ====================================================================================================
# EPOCH: 6/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 35.91%
# 	Loss: 3.3561
# ====================================================================================================
# EPOCH: 7/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 35.90%
# 	Loss: 3.3504
# ====================================================================================================
# EPOCH: 8/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 36.25%
# 	Loss: 3.3369
# ====================================================================================================
# EPOCH: 9/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 36.68%
# 	Loss: 3.3219
# ====================================================================================================
# EPOCH: 10/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 36.28%
# 	Loss: 3.3207
# ====================================================================================================
# EPOCH: 11/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 36.88%
# 	Loss: 3.3043
# ====================================================================================================
# EPOCH: 12/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 36.64%
# 	Loss: 3.3011
# ====================================================================================================
# EPOCH: 13/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 36.74%
# 	Loss: 3.2991
# ====================================================================================================
# EPOCH: 14/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 36.89%
# 	Loss: 3.2972
# ====================================================================================================
# EPOCH: 15/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.05%
# 	Loss: 3.2855
# ====================================================================================================
# EPOCH: 16/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.20%
# 	Loss: 3.2857
# ====================================================================================================
# EPOCH: 17/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.41%
# 	Loss: 3.2636
# ====================================================================================================
# EPOCH: 18/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.39%
# 	Loss: 3.2705
# ====================================================================================================
# EPOCH: 19/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.59%
# 	Loss: 3.2631
# ====================================================================================================
# EPOCH: 20/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.69%
# 	Loss: 3.2557
# ====================================================================================================
# EPOCH: 21/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.86%
# 	Loss: 3.2440
# ====================================================================================================
# EPOCH: 22/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.00%
# 	Loss: 3.2455
# ====================================================================================================
# EPOCH: 23/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.09%
# 	Loss: 3.2365
# ====================================================================================================
# EPOCH: 24/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.18%
# 	Loss: 3.2335
# ====================================================================================================
# EPOCH: 25/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.07%
# 	Loss: 3.2359
# ====================================================================================================
# EPOCH: 26/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 37.96%
# 	Loss: 3.2306
# ====================================================================================================
# EPOCH: 27/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.58%
# 	Loss: 3.2125
# ====================================================================================================
# EPOCH: 28/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.86%
# 	Loss: 3.2075
# ====================================================================================================
# EPOCH: 29/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.85%
# 	Loss: 3.1984
# ====================================================================================================
# EPOCH: 30/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.76%
# 	Loss: 3.1989
# ====================================================================================================
# EPOCH: 31/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.96%
# 	Loss: 3.1878
# ====================================================================================================
# EPOCH: 32/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.10%
# 	Loss: 3.1863
# ====================================================================================================
# EPOCH: 33/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.75%
# 	Loss: 3.2030
# ====================================================================================================
# EPOCH: 34/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 38.94%
# 	Loss: 3.1937
# ====================================================================================================
# EPOCH: 35/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.29%
# 	Loss: 3.1771
# ====================================================================================================
# EPOCH: 36/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.11%
# 	Loss: 3.1756
# ====================================================================================================
# EPOCH: 37/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.66%
# 	Loss: 3.1603
# ====================================================================================================
# EPOCH: 38/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.36%
# 	Loss: 3.1622
# ====================================================================================================
# EPOCH: 39/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.33%
# 	Loss: 3.1762
# ====================================================================================================
# EPOCH: 40/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.95%
# 	Loss: 3.1652
# ====================================================================================================
# EPOCH: 41/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 39.95%
# 	Loss: 3.1371
# ====================================================================================================
# EPOCH: 42/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.22%
# 	Loss: 3.1314
# ====================================================================================================
# EPOCH: 43/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.58%
# 	Loss: 3.1149
# ====================================================================================================
# EPOCH: 44/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.46%
# 	Loss: 3.1169
# ====================================================================================================
# EPOCH: 45/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.64%
# 	Loss: 3.1123
# ====================================================================================================
# EPOCH: 46/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.27%
# 	Loss: 3.1176
# ====================================================================================================
# EPOCH: 47/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.38%
# 	Loss: 3.1229
# ====================================================================================================
# EPOCH: 48/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.69%
# 	Loss: 3.1187
# ====================================================================================================
# EPOCH: 49/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.79%
# 	Loss: 3.1122
# ====================================================================================================
# EPOCH: 50/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.56%
# 	Loss: 3.1065
# ====================================================================================================
# EPOCH: 51/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 40.93%
# 	Loss: 3.0830
# ====================================================================================================
# EPOCH: 52/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.26%
# 	Loss: 3.0743
# ====================================================================================================
# EPOCH: 53/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.04%
# 	Loss: 3.0803
# ====================================================================================================
# EPOCH: 54/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.54%
# 	Loss: 3.0659
# ====================================================================================================
# EPOCH: 55/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.56%
# 	Loss: 3.0582
# ====================================================================================================
# EPOCH: 56/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.84%
# 	Loss: 3.0584
# ====================================================================================================
# EPOCH: 57/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.59%
# 	Loss: 3.0564
# ====================================================================================================
# EPOCH: 58/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.51%
# 	Loss: 3.0576
# ====================================================================================================
# EPOCH: 59/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.37%
# 	Loss: 3.0523
# ====================================================================================================
# EPOCH: 60/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 41.80%
# 	Loss: 3.0464
# ====================================================================================================
# EPOCH: 61/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.05%
# 	Loss: 3.0377
# ====================================================================================================
# EPOCH: 62/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.11%
# 	Loss: 3.0360
# ====================================================================================================
# EPOCH: 63/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.60%
# 	Loss: 3.0162
# ====================================================================================================
# EPOCH: 64/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.10%
# 	Loss: 3.0162
# ====================================================================================================
# EPOCH: 65/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.29%
# 	Loss: 3.0157
# ====================================================================================================
# EPOCH: 66/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.33%
# 	Loss: 3.0087
# ====================================================================================================
# EPOCH: 67/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.68%
# 	Loss: 3.0033
# ====================================================================================================
# EPOCH: 68/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.83%
# 	Loss: 2.9967
# ====================================================================================================
# EPOCH: 69/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.94%
# 	Loss: 2.9893
# ====================================================================================================
# EPOCH: 70/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.01%
# 	Loss: 2.9937
# ====================================================================================================
# EPOCH: 71/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.02%
# 	Loss: 2.9886
# ====================================================================================================
# EPOCH: 72/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.13%
# 	Loss: 2.9733
# ====================================================================================================
# EPOCH: 73/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.17%
# 	Loss: 2.9798
# ====================================================================================================
# EPOCH: 74/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.28%
# 	Loss: 2.9790
# ====================================================================================================
# EPOCH: 75/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.45%
# 	Loss: 2.9681
# ====================================================================================================
# EPOCH: 76/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.44%
# 	Loss: 2.9735
# ====================================================================================================
# EPOCH: 77/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 42.83%
# 	Loss: 2.9848
# ====================================================================================================
# EPOCH: 78/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.35%
# 	Loss: 2.9697
# ====================================================================================================
# EPOCH: 79/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.69%
# 	Loss: 2.9616
# ====================================================================================================
# EPOCH: 80/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 43.87%
# 	Loss: 2.9436
# ====================================================================================================
# EPOCH: 81/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.06%
# 	Loss: 2.9342
# ====================================================================================================
# EPOCH: 82/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.21%
# 	Loss: 2.9285
# ====================================================================================================
# EPOCH: 83/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.20%
# 	Loss: 2.9302
# ====================================================================================================
# EPOCH: 84/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.26%
# 	Loss: 2.9266
# ====================================================================================================
# EPOCH: 85/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.19%
# 	Loss: 2.9254
# ====================================================================================================
# EPOCH: 86/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.53%
# 	Loss: 2.9157
# ====================================================================================================
# EPOCH: 87/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.44%
# 	Loss: 2.9273
# ====================================================================================================
# EPOCH: 88/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.20%
# 	Loss: 2.9265
# ====================================================================================================
# EPOCH: 89/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.52%
# 	Loss: 2.9263
# ====================================================================================================
# EPOCH: 90/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.71%
# 	Loss: 2.9054
# ====================================================================================================
# EPOCH: 91/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.79%
# 	Loss: 2.9007
# ====================================================================================================
# EPOCH: 92/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 44.95%
# 	Loss: 2.8911
# ====================================================================================================
# EPOCH: 93/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.13%
# 	Loss: 2.8785
# ====================================================================================================
# EPOCH: 94/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.25%
# 	Loss: 2.8713
# ====================================================================================================
# EPOCH: 95/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.22%
# 	Loss: 2.8738
# ====================================================================================================
# EPOCH: 96/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.22%
# 	Loss: 2.8728
# ====================================================================================================
# EPOCH: 97/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.16%
# 	Loss: 2.8833
# ====================================================================================================
# EPOCH: 98/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.23%
# 	Loss: 2.8677
# ====================================================================================================
# EPOCH: 99/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.45%
# 	Loss: 2.8564
# ====================================================================================================
# EPOCH: 100/100:
# ----------------------------------------------------------------------------------------------------
# 	Correct Predictions (Train Dataset): 45.86%
# 	Loss: 2.8508
# Best Model Accuracy:  45.86334314523705
# CPU times: user 22min 36s, sys: 10.7 s, total: 22min 47s
# Wall time: 23min

# %%
print(f"Best Accuracy: {best_accuracy:.2f}%")
# Out:
# Best Accuracy: 45.86%

# %%
best_model = Model(embedding_dim, hidden_dim, output_dim, num_layers, dropout)
best_model.load_state_dict(torch.load("/kaggle/working/best_model.pth", weights_only = True))
# Out:
# <All keys matched successfully>

# %%
best_model.eval()

def generate(prompt, idx2word=idx2word):
    prompt = clean_text(prompt)
    prompt = prompt.lower()
    prompt = prompt.split()
    prompt_tokens = tokenize(prompt)
    prompt_embeddings = embeddings(prompt_tokens)
    
    prompt_tensors = torch.tensor(prompt_embeddings, dtype=torch.float32)
    prompt_tensors = prompt_tensors.unsqueeze(0)
    with torch.no_grad():
        output = best_model(prompt_tensors) 
        preds = torch.argmax(output, dim=1)

    character = idx2word[preds.item()]
    return " ".join(prompt) + " " + character 

def generate_text(prompt):
    text = prompt
    for i in range(10):
        text = generate(text)
    return text

# %%
prompt = "By God's grace "
generated_text = generate_text(prompt)
print(generated_text)
# Out:
# by gods grace it to point our eyes which in all wretched blood

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def compute_bleu(model, test_sentences):
    model.eval()
    total_bleu = 0
    count = 0
    smoothing = SmoothingFunction().method1

    for sentence in test_sentences:
        predicted_sentence = generate_text(sentence)
        
        if not predicted_sentence.strip(): 
            continue  
       
        reference = [nltk.word_tokenize(sentence)]
        candidate = nltk.word_tokenize(predicted_sentence)

        bleu_score = sentence_bleu(reference, candidate, smoothing_function=smoothing)
        total_bleu += bleu_score
        count += 1

    return total_bleu / count if count > 0 else 0  # Avoid division by zero

test_sentences = [
    "Methinks the night be filled with dreams untold, where lovers’ sighs do dance upon the air.",
    "Thou art the fairest star that lights my path, and yet thy love doth fade as morning mist.",
    "O gentle breeze, dost thou carry word of love, or sighs of sorrow lost to time’s embrace?",
    "Upon this parchment doth my heart confess, in ink of longing and of love’s despair.",
    "Wouldst thou grant me but a fleeting glance, ere time dost steal thy visage from mine eyes?",
    "The wretched night doth linger long, and yet no solace greets my weary soul.",
    "Lo! The heavens weep with trembling stars, as though the gods dost mourn love’s cruel fate.",
    "A kiss, my love, and all the world is naught but echoes of thy whispered name.",
    "The dawn doth break, yet in mine heart remains the shadow of the night’s sweet sorrow."
]

bleu = compute_bleu(model, test_sentences)
print(f"BLEU Score: {bleu:.4f}")
# Out:
# BLEU Score: 0.4227
